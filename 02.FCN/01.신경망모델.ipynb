# %% [markdown]
# ## 신경망 모델
# #### - 이진 분류: 유방암 예측 사례

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 준비

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
cancer = load_breast_cancer()
cancer.data.shape
# Out:
# (569, 30)

# %%
cancer_std = StandardScaler().fit_transform(cancer.data)

# %% [markdown]
# #### 1. 데이터를 정규/표준화 하지 않은 경우

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %% [markdown]
# - 모델 정의

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense       # Fully Connected Network

# %%
model = Sequential([
    Dense(100, input_dim=30, activation='relu'),
    Dense(24, activation='relu'),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 100)               3100
#
#  dense_4 (Dense)             (None, 24)                2424
#
#  dense_5 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - 모델 설정(컴파일)

# %%
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 모델 학습

# %%
history = model.fit(X_train, y_train,
                    validation_split=0.2,       # 학습중 검증용
                    epochs=100,                 # 반복 횟수
                    batch_size=100)             # 동시에 몇개의 데이터를 메모리에 로드하는가
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 86ms/step - loss: 57.8481 - accuracy: 0.3599 - val_loss: 21.2409 - val_accuracy: 0.4286
# Epoch 2/100
# 4/4 [==============================] - 0s 15ms/step - loss: 12.4130 - accuracy: 0.4753 - val_loss: 22.0145 - val_accuracy: 0.5714
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 14.2760 - accuracy: 0.6401 - val_loss: 3.0883 - val_accuracy: 0.6374
# Epoch 4/100
# 4/4 [==============================] - 0s 15ms/step - loss: 4.8789 - accuracy: 0.4423 - val_loss: 8.1971 - val_accuracy: 0.4286
# Epoch 5/100
# 4/4 [==============================] - 0s 18ms/step - loss: 6.1124 - accuracy: 0.3819 - val_loss: 0.9811 - val_accuracy: 0.7802
# Epoch 6/100
# 4/4 [==============================] - 0s 15ms/step - loss: 2.7364 - accuracy: 0.7582 - val_loss: 3.4578 - val_accuracy: 0.7033
# Epoch 7/100
# 4/4 [==============================] - 0s 15ms/step - loss: 1.6322 - accuracy: 0.8077 - val_loss: 1.7037 - val_accuracy: 0.6044
# Epoch 8/100
# 4/4 [==============================] - 0s 16ms/step - loss: 1.2140 - accuracy: 0.6786 - val_loss: 0.1869 - val_accuracy: 0.9341
# Epoch 9/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.6375 - accuracy: 0.8819 - val_loss: 0.2933 - val_accuracy: 0.8791
# Epoch 10/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.5076 - accuracy: 0.8791 - val_loss: 0.6896 - val_accuracy: 0.7802
# Epoch 11/100
# 4/4 [==============================] - 0s 31ms/step - loss: 0.4886 - accuracy: 0.8434 - val_loss: 0.1610 - val_accuracy: 0.9451
# Epoch 12/100
# 4/4 [==============================] - 0s 18ms/step - loss: 0.4312 - accuracy: 0.9093 - val_loss: 0.2365 - val_accuracy: 0.9231
# Epoch 13/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3213 - accuracy: 0.9231 - val_loss: 0.4497 - val_accuracy: 0.8462
# Epoch 14/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.4037 - accuracy: 0.8626 - val_loss: 0.1776 - val_accuracy: 0.9341
# Epoch 15/100
# 4/4 [==============================] - 0s 17ms/step - loss: 0.3399 - accuracy: 0.9203 - val_loss: 0.1830 - val_accuracy: 0.9231
# Epoch 16/100
# 4/4 [==============================] - 0s 30ms/step - loss: 0.2720 - accuracy: 0.9176 - val_loss: 0.3229 - val_accuracy: 0.8571
# Epoch 17/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.3083 - accuracy: 0.9093 - val_loss: 0.1808 - val_accuracy: 0.9341
# Epoch 18/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2504 - accuracy: 0.9148 - val_loss: 0.1728 - val_accuracy: 0.9451
# Epoch 19/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2503 - accuracy: 0.9148 - val_loss: 0.2520 - val_accuracy: 0.9121
# Epoch 20/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1624 - accuracy: 0.9341 - val_loss: 0.1698 - val_accuracy: 0.9341
# Epoch 83/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1612 - accuracy: 0.9341 - val_loss: 0.1475 - val_accuracy: 0.9341
# Epoch 84/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1604 - accuracy: 0.9258 - val_loss: 0.1942 - val_accuracy: 0.9341
# Epoch 85/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.2158 - accuracy: 0.9176 - val_loss: 0.1455 - val_accuracy: 0.9231
# Epoch 86/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2188 - accuracy: 0.9093 - val_loss: 0.1572 - val_accuracy: 0.9341
# Epoch 87/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1616 - accuracy: 0.9258 - val_loss: 0.1780 - val_accuracy: 0.9341
# Epoch 88/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1724 - accuracy: 0.9313 - val_loss: 0.1439 - val_accuracy: 0.9231
# Epoch 89/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1519 - accuracy: 0.9396 - val_loss: 0.1511 - val_accuracy: 0.9451
# Epoch 90/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1572 - accuracy: 0.9423 - val_loss: 0.1433 - val_accuracy: 0.9231
# Epoch 91/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1707 - accuracy: 0.9341 - val_loss: 0.1513 - val_accuracy: 0.9341
# Epoch 92/100
# 4/4 [==============================] - 0s 15ms/step - loss: 0.1761 - accuracy: 0.9231 - val_loss: 0.1503 - val_accuracy: 0.9341
# Epoch 93/100
# 4/4 [==============================] - 0s 32ms/step - loss: 0.1573 - accuracy: 0.9396 - val_loss: 0.1582 - val_accuracy: 0.9451
# Epoch 94/100
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1626 - accuracy: 0.9258 - val_loss: 0.1664 - val_accuracy: 0.9341
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1612 - accuracy: 0.9341 - val_loss: 0.1460 - val_accuracy: 0.9231
# Epoch 96/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1700 - accuracy: 0.9341 - val_loss: 0.1896 - val_accuracy: 0.9231
# Epoch 97/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2000 - accuracy: 0.9231 - val_loss: 0.2083 - val_accuracy: 0.9231
# Epoch 98/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1398 - accuracy: 0.9478 - val_loss: 0.2231 - val_accuracy: 0.9231
# Epoch 99/100
# 4/4 [==============================] - 0s 14ms/step - loss: 0.2019 - accuracy: 0.9231 - val_loss: 0.1857 - val_accuracy: 0.9341
# Epoch 100/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2155 - accuracy: 0.9203 - val_loss: 0.1691 - val_accuracy: 0.9341

# %% [markdown]
# - 모델 평가

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1760 - accuracy: 0.9123
# [0.17599958181381226, 0.9122806787490845]

# %% [markdown]
# - 훈련과정 시각화
#     - epoch에 따른 accuracy, val_loss의 변화

# %%
y_acc = history.history['accuracy']
y_vloss = history.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1]), plt.xlabel('Epoch')
plt.title('No feature transformation')
plt.show()

# %% [markdown]
# #### 2. 데이터를 표준화한 경우

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    cancer_std, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %%
# 모델 정의
model2 = Sequential()
model2.add(Dense(100, input_shape=(30,), activation='relu'))
model2.add(Dense(24, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 100)               3100
#
#  dense_7 (Dense)             (None, 24)                2424
#
#  dense_8 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 컴파일
model2.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
# 모델 학습
history2 = model2.fit(X_train2, y_train2, validation_split=0.2,
                      epochs=100, batch_size=100, verbose=0)

# %%
# 모델 평가
model2.evaluate(X_test2, y_test2)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2064 - accuracy: 0.9561
# [0.20640574395656586, 0.9561403393745422]

# %%
# 학습과정 시각화
y_acc2 = history2.history['accuracy']
y_vloss2 = history2.history['val_loss']

plt.figure(figsize=(12,7))
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1.1]), plt.xlabel('Epoch')
plt.title('With feature transformation')
plt.show()
