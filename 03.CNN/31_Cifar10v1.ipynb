# %% [markdown]
# ## Cifar-10 이미지 분류 v1
# - Cifar-10(Canadian Institute for Advanced Research, 10 classes)

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
seed = 2023
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# - 데이터 탐색 및 전처리

# %%
from tensorflow.keras.datasets import cifar10
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 4s 0us/step

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((50000, 32, 32, 3), (50000, 1), (10000, 32, 32, 3), (10000, 1))

# %%
class_names = ['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']

plt.figure(figsize=(8,2))
for i in range(10):
    plt.subplot(1,10,i+1)
    plt.imshow(X_train[i]), plt.xticks([]), plt.yticks([])
    plt.title(class_names[y_train[i,0]], fontsize=8)
plt.show()

# %%
# X data: scaling
X_train = X_train / 255.
X_test = X_test / 255.

# %%
# y data: one hot encoding
from tensorflow.keras.utils import to_categorical
Y_train = to_categorical(y_train)
Y_test = to_categorical(y_test)

# %% [markdown]
# - 모델 정의/설정/학습/평가

# %%
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
model = Sequential([
    Conv2D(32, (3,3), input_shape=X_train.shape[1:], padding='same', activation='relu'),
    Conv2D(32, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, (3,3), padding='same', activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  conv2d_1 (Conv2D)           (None, 30, 30, 32)        9248
#
#  max_pooling2d (MaxPooling2  (None, 15, 15, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 15, 15, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 15, 15, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 13, 13, 64)        36928
#
#  max_pooling2d_1 (MaxPoolin  (None, 6, 6, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 6, 6, 64)          0
#
#  flatten (Flatten)           (None, 2304)              0
#
#  dense (Dense)               (None, 512)               1180160
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 10)                5130
#
# =================================================================
# Total params: 1250858 (4.77 MB)
# Trainable params: 1250858 (4.77 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile('adam', 'categorical_crossentropy', ['accuracy'])

model_path = 'best-cifar10-v1.h5'
mc = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
es = EarlyStopping(patience=5)

# %%
hist = model.fit(X_train, Y_train, validation_split=0.2,
                 epochs=100, batch_size=32, callbacks=[mc,es])
# Out:
# Epoch 1/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.5936 - accuracy: 0.4134
# Epoch 1: val_loss improved from inf to 1.26963, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 21s 7ms/step - loss: 1.5934 - accuracy: 0.4135 - val_loss: 1.2696 - val_accuracy: 0.5441
# Epoch 2/100
#   21/1250 [..............................] - ETA: 6s - loss: 1.2939 - accuracy: 0.5060
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1249/1250 [============================>.] - ETA: 0s - loss: 1.2163 - accuracy: 0.5652
# Epoch 2: val_loss improved from 1.26963 to 1.01185, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 1.2162 - accuracy: 0.5652 - val_loss: 1.0118 - val_accuracy: 0.6404
# Epoch 3/100
# 1248/1250 [============================>.] - ETA: 0s - loss: 1.0401 - accuracy: 0.6338
# Epoch 3: val_loss improved from 1.01185 to 0.93111, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 1.0398 - accuracy: 0.6340 - val_loss: 0.9311 - val_accuracy: 0.6732
# Epoch 4/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.9355 - accuracy: 0.6702
# Epoch 4: val_loss did not improve from 0.93111
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.9355 - accuracy: 0.6702 - val_loss: 0.9934 - val_accuracy: 0.6518
# Epoch 5/100
# 1250/1250 [==============================] - ETA: 0s - loss: 0.8593 - accuracy: 0.6995
# Epoch 5: val_loss improved from 0.93111 to 0.80386, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.8593 - accuracy: 0.6995 - val_loss: 0.8039 - val_accuracy: 0.7237
# Epoch 6/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.8004 - accuracy: 0.7165
# Epoch 6: val_loss improved from 0.80386 to 0.75496, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.8010 - accuracy: 0.7166 - val_loss: 0.7550 - val_accuracy: 0.7412
# Epoch 7/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.7577 - accuracy: 0.7338
# Epoch 7: val_loss improved from 0.75496 to 0.73328, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.7574 - accuracy: 0.7339 - val_loss: 0.7333 - val_accuracy: 0.7468
# Epoch 8/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.7167 - accuracy: 0.7487
# Epoch 8: val_loss improved from 0.73328 to 0.71609, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.7162 - accuracy: 0.7489 - val_loss: 0.7161 - val_accuracy: 0.7521
# Epoch 9/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.6874 - accuracy: 0.7586
# Epoch 9: val_loss improved from 0.71609 to 0.71224, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6872 - accuracy: 0.7588 - val_loss: 0.7122 - val_accuracy: 0.7590
# Epoch 10/100
# 1241/1250 [============================>.] - ETA: 0s - loss: 0.6504 - accuracy: 0.7700
# Epoch 10: val_loss improved from 0.71224 to 0.70151, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6506 - accuracy: 0.7698 - val_loss: 0.7015 - val_accuracy: 0.7621
# Epoch 11/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.6310 - accuracy: 0.7757
# Epoch 11: val_loss did not improve from 0.70151
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.6307 - accuracy: 0.7759 - val_loss: 0.7163 - val_accuracy: 0.7601
# Epoch 12/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.6077 - accuracy: 0.7859
# Epoch 12: val_loss improved from 0.70151 to 0.67536, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.6070 - accuracy: 0.7861 - val_loss: 0.6754 - val_accuracy: 0.7727
# Epoch 13/100
# 1246/1250 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.7920
# Epoch 13: val_loss did not improve from 0.67536
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.5879 - accuracy: 0.7922 - val_loss: 0.6833 - val_accuracy: 0.7689
# Epoch 14/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.5691 - accuracy: 0.8011
# Epoch 14: val_loss did not improve from 0.67536
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.5692 - accuracy: 0.8012 - val_loss: 0.7548 - val_accuracy: 0.7507
# Epoch 15/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.5482 - accuracy: 0.8083
# Epoch 15: val_loss did not improve from 0.67536
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.5482 - accuracy: 0.8083 - val_loss: 0.7398 - val_accuracy: 0.7578
# Epoch 16/100
# 1242/1250 [============================>.] - ETA: 0s - loss: 0.5305 - accuracy: 0.8136
# Epoch 16: val_loss did not improve from 0.67536
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5312 - accuracy: 0.8133 - val_loss: 0.7093 - val_accuracy: 0.7683
# Epoch 17/100
# 1245/1250 [============================>.] - ETA: 0s - loss: 0.5171 - accuracy: 0.8188
# Epoch 17: val_loss improved from 0.67536 to 0.66252, saving model to best-cifar10-v1.h5
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.5173 - accuracy: 0.8185 - val_loss: 0.6625 - val_accuracy: 0.7806
# Epoch 18/100
# 1243/1250 [============================>.] - ETA: 0s - loss: 0.4987 - accuracy: 0.8243
# Epoch 18: val_loss did not improve from 0.66252
# 1250/1250 [==============================] - 9s 7ms/step - loss: 0.4997 - accuracy: 0.8239 - val_loss: 0.6808 - val_accuracy: 0.7786
# Epoch 19/100
# 1249/1250 [============================>.] - ETA: 0s - loss: 0.4967 - accuracy: 0.8266
# Epoch 19: val_loss did not improve from 0.66252
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4967 - accuracy: 0.8267 - val_loss: 0.7040 - val_accuracy: 0.7677
# Epoch 20/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.4775 - accuracy: 0.8324
# Epoch 20: val_loss did not improve from 0.66252
# 1250/1250 [==============================] - 7s 6ms/step - loss: 0.4768 - accuracy: 0.8326 - val_loss: 0.6703 - val_accuracy: 0.7842
# Epoch 21/100
# 1247/1250 [============================>.] - ETA: 0s - loss: 0.4682 - accuracy: 0.8346
# Epoch 21: val_loss did not improve from 0.66252
# 1250/1250 [==============================] - 8s 7ms/step - loss: 0.4682 - accuracy: 0.8346 - val_loss: 0.6645 - val_accuracy: 0.7906
# Epoch 22/100
# 1244/1250 [============================>.] - ETA: 0s - loss: 0.4587 - accuracy: 0.8386
# Epoch 22: val_loss did not improve from 0.66252
# 1250/1250 [==============================] - 8s 6ms/step - loss: 0.4592 - accuracy: 0.8385 - val_loss: 0.6785 - val_accuracy: 0.7892

# %%
best_model = load_model(model_path)
best_model.evaluate(X_test, Y_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6709 - accuracy: 0.7790
# [0.6708692908287048, 0.7789999842643738]

# %% [markdown]
# - 시각화

# %%
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid(), plt.xlabel('epoch')
plt.title('Cifar-10 CNN Model v1')
plt.show()
